# %% [markdown]
# ### Import Dependencies

# %%
import os
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler, MinMaxScaler

pd.options.display.max_columns = None

# %% [markdown]
# ### Loading the Data

# %%
df = pd.read_csv('data/processed/6_feature_encoded.csv')
df
# Out:
#       Contract  MonthlyCharges  TotalCharges  Churn  ServiceAdoptionScore  \
# 0            0           29.85         29.85      0                     1
# 1            1           56.95       1889.50      0                     2
# 2            0           53.85        108.15      1                     2
# 3            1           42.30       1840.75      0                     3
# 4            0           70.70        151.65      1                     0
# ...        ...             ...           ...    ...                   ...
# 7038         1           84.80       1990.50      0                     5
# 7039         1          103.20       7362.90      0                     4
# 7040         0           29.60        346.45      0                     1
# 7041         0           74.40        306.60      1                     0
# 7042         2          105.65       6844.50      0                     5
#
#       AvgChargePerService  TenureBins  gender_Male  SeniorCitizen_1  \
# 0               14.925000           0        False            False
# 1               18.983333           1         True            False
# 2               17.950000           0         True            False
# 3               10.575000           1         True            False
# 4               70.700000           0        False            False
# ...                   ...         ...          ...              ...
# 7038            14.133333           1         True            False
# 7039            20.640000           2        False            False
# 7040            14.800000           0        False            False
# 7041            74.400000           0         True             True
# 7042            17.608333           2         True            False
#
#       Partner_Yes  Dependents_Yes  PhoneService_Yes  \
# 0            True           False             False
# 1           False           False              True
# 2           False           False              True
# 3           False           False             False
# 4           False           False              True
# ...           ...             ...               ...
# 7038         True            True              True
# 7039         True            True              True
# 7040         True            True             False
# 7041         True           False              True
# 7042        False           False              True
#
#       MultipleLines_No phone service  MultipleLines_Yes  \
# 0                               True              False
# 1                              False              False
# 2                              False              False
# 3                               True              False
# 4                              False              False
# ...                              ...                ...
# 7038                           False               True
# 7039                           False               True
# 7040                            True              False
# 7041                           False               True
# 7042                           False              False
#
#       InternetService_Fiber optic  InternetService_No  \
# 0                           False               False
# 1                           False               False
# 2                           False               False
# 3                           False               False
# 4                            True               False
# ...                           ...                 ...
# 7038                        False               False
# 7039                         True               False
# 7040                        False               False
# 7041                         True               False
# 7042                         True               False
#
#       OnlineSecurity_No internet service  OnlineSecurity_Yes  \
# 0                                  False               False
# 1                                  False                True
# 2                                  False                True
# 3                                  False                True
# 4                                  False               False
# ...                                  ...                 ...
# 7038                               False                True
# 7039                               False               False
# 7040                               False                True
# 7041                               False               False
# 7042                               False                True
#
#       OnlineBackup_No internet service  OnlineBackup_Yes  \
# 0                                False              True
# 1                                False             False
# 2                                False              True
# 3                                False             False
# 4                                False             False
# ...                                ...               ...
# 7038                             False             False
# 7039                             False              True
# 7040                             False             False
# 7041                             False             False
# 7042                             False             False
#
#       DeviceProtection_No internet service  DeviceProtection_Yes  \
# 0                                    False                 False
# 1                                    False                  True
# 2                                    False                 False
# 3                                    False                  True
# 4                                    False                 False
# ...                                    ...                   ...
# 7038                                 False                  True
# 7039                                 False                  True
# 7040                                 False                 False
# 7041                                 False                 False
# 7042                                 False                  True
#
#       TechSupport_No internet service  TechSupport_Yes  \
# 0                               False            False
# 1                               False            False
# 2                               False            False
# 3                               False             True
# 4                               False            False
# ...                               ...              ...
# 7038                            False             True
# 7039                            False            False
# 7040                            False            False
# 7041                            False            False
# 7042                            False             True
#
#       StreamingTV_No internet service  StreamingTV_Yes  \
# 0                               False            False
# 1                               False            False
# 2                               False            False
# 3                               False            False
# 4                               False            False
# ...                               ...              ...
# 7038                            False             True
# 7039                            False             True
# 7040                            False            False
# 7041                            False            False
# 7042                            False             True
#
#       StreamingMovies_No internet service  StreamingMovies_Yes  \
# 0                                   False                False
# 1                                   False                False
# 2                                   False                False
# 3                                   False                False
# 4                                   False                False
# ...                                   ...                  ...
# 7038                                False                 True
# 7039                                False                 True
# 7040                                False                False
# 7041                                False                False
# 7042                                False                 True
#
#       PaperlessBilling_Yes  PaymentReliabilityIndicator_Unreliable
# 0                     True                                    True
# 1                    False                                    True
# 2                     True                                    True
# 3                    False                                   False
# 4                     True                                    True
# ...                    ...                                     ...
# 7038                  True                                    True
# 7039                  True                                   False
# 7040                  True                                    True
# 7041                  True                                    True
# 7042                  True                                   False
#
# [7043 rows x 30 columns]

# %%
columns_to_scale = ['MonthlyCharges', 'TotalCharges', 'AvgChargePerService']

for col in columns_to_scale:
    scaler = StandardScaler()
    df[col] = scaler.fit_transform(df[[col]])

df
# Out:
#       Contract  MonthlyCharges  TotalCharges  Churn  ServiceAdoptionScore  \
# 0            0       -1.160323     -0.994971      0                     1
# 1            1       -0.259629     -0.173876      0                     2
# 2            0       -0.362660     -0.960399      1                     2
# 3            1       -0.746535     -0.195400      0                     3
# 4            0        0.197365     -0.941193      1                     0
# ...        ...             ...           ...    ...                   ...
# 7038         1        0.665992     -0.129281      0                     5
# 7039         1        1.277533      2.242808      0                     4
# 7040         0       -1.168632     -0.855182      0                     1
# 7041         0        0.320338     -0.872777      1                     0
# 7042         2        1.358961      2.013917      0                     5
#
#       AvgChargePerService  TenureBins  gender_Male  SeniorCitizen_1  \
# 0               -0.749701           0        False            False
# 1               -0.461719           1         True            False
# 2               -0.535045           0         True            False
# 3               -1.058380           1         True            False
# 4                3.208130           0        False            False
# ...                   ...         ...          ...              ...
# 7038            -0.805878           1         True            False
# 7039            -0.344161           2        False            False
# 7040            -0.758571           0        False            False
# 7041             3.470685           0         True             True
# 7042            -0.559290           2         True            False
#
#       Partner_Yes  Dependents_Yes  PhoneService_Yes  \
# 0            True           False             False
# 1           False           False              True
# 2           False           False              True
# 3           False           False             False
# 4           False           False              True
# ...           ...             ...               ...
# 7038         True            True              True
# 7039         True            True              True
# 7040         True            True             False
# 7041         True           False              True
# 7042        False           False              True
#
#       MultipleLines_No phone service  MultipleLines_Yes  \
# 0                               True              False
# 1                              False              False
# 2                              False              False
# 3                               True              False
# 4                              False              False
# ...                              ...                ...
# 7038                           False               True
# 7039                           False               True
# 7040                            True              False
# 7041                           False               True
# 7042                           False              False
#
#       InternetService_Fiber optic  InternetService_No  \
# 0                           False               False
# 1                           False               False
# 2                           False               False
# 3                           False               False
# 4                            True               False
# ...                           ...                 ...
# 7038                        False               False
# 7039                         True               False
# 7040                        False               False
# 7041                         True               False
# 7042                         True               False
#
#       OnlineSecurity_No internet service  OnlineSecurity_Yes  \
# 0                                  False               False
# 1                                  False                True
# 2                                  False                True
# 3                                  False                True
# 4                                  False               False
# ...                                  ...                 ...
# 7038                               False                True
# 7039                               False               False
# 7040                               False                True
# 7041                               False               False
# 7042                               False                True
#
#       OnlineBackup_No internet service  OnlineBackup_Yes  \
# 0                                False              True
# 1                                False             False
# 2                                False              True
# 3                                False             False
# 4                                False             False
# ...                                ...               ...
# 7038                             False             False
# 7039                             False              True
# 7040                             False             False
# 7041                             False             False
# 7042                             False             False
#
#       DeviceProtection_No internet service  DeviceProtection_Yes  \
# 0                                    False                 False
# 1                                    False                  True
# 2                                    False                 False
# 3                                    False                  True
# 4                                    False                 False
# ...                                    ...                   ...
# 7038                                 False                  True
# 7039                                 False                  True
# 7040                                 False                 False
# 7041                                 False                 False
# 7042                                 False                  True
#
#       TechSupport_No internet service  TechSupport_Yes  \
# 0                               False            False
# 1                               False            False
# 2                               False            False
# 3                               False             True
# 4                               False            False
# ...                               ...              ...
# 7038                            False             True
# 7039                            False            False
# 7040                            False            False
# 7041                            False            False
# 7042                            False             True
#
#       StreamingTV_No internet service  StreamingTV_Yes  \
# 0                               False            False
# 1                               False            False
# 2                               False            False
# 3                               False            False
# 4                               False            False
# ...                               ...              ...
# 7038                            False             True
# 7039                            False             True
# 7040                            False            False
# 7041                            False            False
# 7042                            False             True
#
#       StreamingMovies_No internet service  StreamingMovies_Yes  \
# 0                                   False                False
# 1                                   False                False
# 2                                   False                False
# 3                                   False                False
# 4                                   False                False
# ...                                   ...                  ...
# 7038                                False                 True
# 7039                                False                 True
# 7040                                False                False
# 7041                                False                False
# 7042                                False                 True
#
#       PaperlessBilling_Yes  PaymentReliabilityIndicator_Unreliable
# 0                     True                                    True
# 1                    False                                    True
# 2                     True                                    True
# 3                    False                                   False
# 4                     True                                    True
# ...                    ...                                     ...
# 7038                  True                                    True
# 7039                  True                                   False
# 7040                  True                                    True
# 7041                  True                                    True
# 7042                  True                                   False
#
# [7043 rows x 30 columns]

# %%
df.to_csv('data/processed/7_feature_scaled.csv', index=False)
