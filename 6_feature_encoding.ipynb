# %% [markdown]
# ### Import Dependencies

# %%
import os
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ### Loading the Data

# %%
df = pd.read_csv('data/processed/5_feature_binned.csv')

# %%
nominal_cols = ["gender", "SeniorCitizen", "Partner", "Dependents",
                "PhoneService", "MultipleLines", "InternetService",
                "OnlineSecurity", "OnlineBackup", "DeviceProtection",
                "TechSupport", "StreamingTV", "StreamingMovies",
                "PaperlessBilling", "PaymentReliabilityIndicator"]

ordinal_cols = ["Contract", "TenureBins"]

# %%
df_encoded = df.copy()
df_encoded
# Out:
#       gender  SeniorCitizen Partner Dependents PhoneService     MultipleLines  \
# 0     Female              0     Yes         No           No  No phone service
# 1       Male              0      No         No          Yes                No
# 2       Male              0      No         No          Yes                No
# 3       Male              0      No         No           No  No phone service
# 4     Female              0      No         No          Yes                No
# ...      ...            ...     ...        ...          ...               ...
# 7038    Male              0     Yes        Yes          Yes               Yes
# 7039  Female              0     Yes        Yes          Yes               Yes
# 7040  Female              0     Yes        Yes           No  No phone service
# 7041    Male              1     Yes         No          Yes               Yes
# 7042    Male              0      No         No          Yes                No
#
#      InternetService OnlineSecurity OnlineBackup DeviceProtection  ...  \
# 0                DSL             No          Yes               No  ...
# 1                DSL            Yes           No              Yes  ...
# 2                DSL            Yes          Yes               No  ...
# 3                DSL            Yes           No              Yes  ...
# 4        Fiber optic             No           No               No  ...
# ...              ...            ...          ...              ...  ...
# 7038             DSL            Yes           No              Yes  ...
# 7039     Fiber optic             No          Yes              Yes  ...
# 7040             DSL            Yes           No               No  ...
# 7041     Fiber optic             No           No               No  ...
# 7042     Fiber optic            Yes           No              Yes  ...
#
#      StreamingMovies        Contract PaperlessBilling MonthlyCharges  \
# 0                 No  Month-to-month              Yes          29.85
# 1                 No        One year               No          56.95
# 2                 No  Month-to-month              Yes          53.85
# 3                 No        One year               No          42.30
# 4                 No  Month-to-month              Yes          70.70
# ...              ...             ...              ...            ...
# 7038             Yes        One year              Yes          84.80
# 7039             Yes        One year              Yes         103.20
# 7040              No  Month-to-month              Yes          29.60
# 7041              No  Month-to-month              Yes          74.40
# 7042             Yes        Two year              Yes         105.65
#
#      TotalCharges  Churn  ServiceAdoptionScore  AvgChargePerService  \
# 0           29.85      0                     1            14.925000
# 1         1889.50      0                     2            18.983333
# 2          108.15      1                     2            17.950000
# 3         1840.75      0                     3            10.575000
# 4          151.65      1                     0            70.700000
# ...           ...    ...                   ...                  ...
# 7038      1990.50      0                     5            14.133333
# 7039      7362.90      0                     4            20.640000
# 7040       346.45      0                     1            14.800000
# 7041       306.60      1                     0            74.400000
# 7042      6844.50      0                     5            17.608333
#
#        TenureBins  PaymentReliabilityIndicator
# 0             New                   Unreliable
# 1     Established                   Unreliable
# 2             New                   Unreliable
# 3     Established                     Reliable
# 4             New                   Unreliable
# ...           ...                          ...
# 7038  Established                   Unreliable
# 7039        Loyal                     Reliable
# 7040          New                   Unreliable
# 7041          New                   Unreliable
# 7042        Loyal                     Reliable
#
# [7043 rows x 22 columns]

# %% [markdown]
# ### Nominal Columns

# %%
for col in nominal_cols:
    dummies = pd.get_dummies(df[col], prefix=col,drop_first=True)
    df_encoded = pd.concat([df_encoded, dummies], axis=1)
    df_encoded.drop(col, axis=1, inplace=True)

df_encoded
# Out:
#             Contract  MonthlyCharges  TotalCharges  Churn  \
# 0     Month-to-month           29.85         29.85      0
# 1           One year           56.95       1889.50      0
# 2     Month-to-month           53.85        108.15      1
# 3           One year           42.30       1840.75      0
# 4     Month-to-month           70.70        151.65      1
# ...              ...             ...           ...    ...
# 7038        One year           84.80       1990.50      0
# 7039        One year          103.20       7362.90      0
# 7040  Month-to-month           29.60        346.45      0
# 7041  Month-to-month           74.40        306.60      1
# 7042        Two year          105.65       6844.50      0
#
#       ServiceAdoptionScore  AvgChargePerService   TenureBins  gender_Male  \
# 0                        1            14.925000          New        False
# 1                        2            18.983333  Established         True
# 2                        2            17.950000          New         True
# 3                        3            10.575000  Established         True
# 4                        0            70.700000          New        False
# ...                    ...                  ...          ...          ...
# 7038                     5            14.133333  Established         True
# 7039                     4            20.640000        Loyal        False
# 7040                     1            14.800000          New        False
# 7041                     0            74.400000          New         True
# 7042                     5            17.608333        Loyal         True
#
#       SeniorCitizen_1  Partner_Yes  ...  DeviceProtection_No internet service  \
# 0               False         True  ...                                 False
# 1               False        False  ...                                 False
# 2               False        False  ...                                 False
# 3               False        False  ...                                 False
# 4               False        False  ...                                 False
# ...               ...          ...  ...                                   ...
# 7038            False         True  ...                                 False
# 7039            False         True  ...                                 False
# 7040            False         True  ...                                 False
# 7041             True         True  ...                                 False
# 7042            False        False  ...                                 False
#
#       DeviceProtection_Yes  TechSupport_No internet service  TechSupport_Yes  \
# 0                    False                            False            False
# 1                     True                            False            False
# 2                    False                            False            False
# 3                     True                            False             True
# 4                    False                            False            False
# ...                    ...                              ...              ...
# 7038                  True                            False             True
# 7039                  True                            False            False
# 7040                 False                            False            False
# 7041                 False                            False            False
# 7042                  True                            False             True
#
#       StreamingTV_No internet service  StreamingTV_Yes  \
# 0                               False            False
# 1                               False            False
# 2                               False            False
# 3                               False            False
# 4                               False            False
# ...                               ...              ...
# 7038                            False             True
# 7039                            False             True
# 7040                            False            False
# 7041                            False            False
# 7042                            False             True
#
#       StreamingMovies_No internet service  StreamingMovies_Yes  \
# 0                                   False                False
# 1                                   False                False
# 2                                   False                False
# 3                                   False                False
# 4                                   False                False
# ...                                   ...                  ...
# 7038                                False                 True
# 7039                                False                 True
# 7040                                False                False
# 7041                                False                False
# 7042                                False                 True
#
#       PaperlessBilling_Yes  PaymentReliabilityIndicator_Unreliable
# 0                     True                                    True
# 1                    False                                    True
# 2                     True                                    True
# 3                    False                                   False
# 4                     True                                    True
# ...                    ...                                     ...
# 7038                  True                                    True
# 7039                  True                                   False
# 7040                  True                                    True
# 7041                  True                                    True
# 7042                  True                                   False
#
# [7043 rows x 30 columns]

# %% [markdown]
# ### Ordinal Columns

# %%
df_encoded['TenureBins'] = df_encoded['TenureBins'].map({'New': 0, 'Established': 1, 'Loyal': 2})
df_encoded['Contract'] = df_encoded['Contract'].map({'Month-to-month': 0, 'One year': 1, 'Two year': 2})

# %%
df_encoded.to_csv('data/processed/6_feature_encoded.csv', index=False)
