# %% [markdown]
# ### Import Dependencies

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### Basic Processing

# %%
df = pd.read_csv('data/processed/1.1_initial_data_assessment_done.csv')
df
# Out:
#       gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0     Female          False     Yes         No       1           No
# 1       Male          False      No         No      34          Yes
# 2       Male          False      No         No       2          Yes
# 3       Male          False      No         No      45           No
# 4     Female          False      No         No       2          Yes
# ...      ...            ...     ...        ...     ...          ...
# 7038    Male          False     Yes        Yes      24          Yes
# 7039  Female          False     Yes        Yes      72          Yes
# 7040  Female          False     Yes        Yes      11           No
# 7041    Male           True     Yes         No       4          Yes
# 7042    Male          False      No         No      66          Yes
#
#          MultipleLines InternetService OnlineSecurity OnlineBackup  \
# 0     No phone service             DSL             No          Yes
# ...

# %%
demographic_cols = ['gender', 'SeniorCitizen', 'Partner', 'Dependents']
behavioral_cols = ['PhoneService', 'MultipleLines', 'InternetService',
                   'OnlineSecurity', 'OnlineBackup', 'DeviceProtection', 'TechSupport',
                   'StreamingTV', 'StreamingMovies', 'Contract', 'PaperlessBilling', 'PaymentMethod']
financial_cols = ['MonthlyCharges', 'TotalCharges']
target_col = 'Churn'

# %% [markdown]
# ### Churn vs Demographics

# %%
fig, axes = plt.subplots(1, 4, figsize=(20,5))
for i, col in enumerate(demographic_cols):
    sns.countplot(x=col, hue=target_col, data=df, ax=axes[i])
    axes[i].set_title(f'{col} vs {target_col}')
    axes[i].set_xlabel(col)
    axes[i].set_ylabel('Count')
    axes[i].legend(title=target_col)

# %% [markdown]
# ### Churn vs Services

# %%
fig, axes = plt.subplots(3, 4, figsize=(20,15))
for i, col in enumerate(behavioral_cols):
    sns.countplot(x=col, hue=target_col, data=df, ax=axes[i//4, i%4])
    axes[i//4, i%4].set_title(f'{col} vs {target_col}')
    axes[i//4, i%4].set_xlabel(col) 
    axes[i//4, i%4].set_ylabel('Count')
    axes[i//4, i%4].legend(title=target_col)
